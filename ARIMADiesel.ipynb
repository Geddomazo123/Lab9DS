# %% [markdown]
# # Modelo ARIMA para forecast

# %% [markdown]
# ## Importación de librerías

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose
import os
from google.colab import files
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
data = files.upload()
# Out:
#      <input type="file" id="files-ab7f077d-1efd-415d-8910-3bdb967c180b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ab7f077d-1efd-415d-8910-3bdb967c180b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving DatosConsumoCombustibles.csv to DatosConsumoCombustibles.csv

# %% [markdown]
# ## Extracción de nombre del archivo

# %%
file_name=list(data.keys())[0]
file_name
# Out:
# 'DatosConsumoCombustibles.csv'

# %%
print(file_name)
# Out:
# DatosConsumoCombustibles.csv

# %% [markdown]
# ## Lectura de datos

# %%
df=pd.read_csv(file_name)
#display(df)
#df=pd.melt(df,id_vars= 'Mes',value_name='Consumo',var_name='Combustible')

df.set_index(pd.date_range(start='2000-01-01', end='2021-06-01',freq='1M',closed='right'),inplace=True)

df.index.name='Fecha'

df.drop(df.index[-4:],axis=0,inplace=True)
df
# Out:
#      Unnamed: 0  Anio  Mes  ...  Orimulsion  MezclasOleosas       Total
# 0             3  2000    1  ...         NaN             NaN  1750544.64
# 1             4  2000    2  ...         NaN             NaN  1773220.22
# 2             5  2000    3  ...         NaN             NaN  1909498.79
# 3             6  2000    4  ...         NaN             NaN  1800932.86
# 4             7  2000    5  ...         NaN             NaN  1941771.90
# ..          ...   ...  ...  ...         ...             ...         ...
# 252         194  2021    1  ...         NaN          285.71  3507363.69
# 253         204  2021    2  ...         NaN             NaN  3644007.36
# 254         214  2021    3  ...         NaN             NaN  3862739.86
# 255         224  2021    4  ...         NaN           83.00  3622666.65
# 256         234  2021    5  ...         NaN          516.70  3830821.05
#
# [257 rows x 27 columns]
#             Unnamed: 0  Anio  Mes  ...  Orimulsion  MezclasOleosas       Total
# Fecha                              ...
# 2000-01-31           3  2000    1  ...         NaN             NaN  1750544.64
# 2000-02-29           4  2000    2  ...         NaN             NaN  1773220.22
# 2000-03-31           5  2000    3  ...         NaN             NaN  1909498.79
# 2000-04-30           6  2000    4  ...         NaN             NaN  1800932.86
# 2000-05-31           7  2000    5  ...         NaN             NaN  1941771.90
# ...                ...   ...  ...  ...         ...             ...         ...
# 2020-09-30         154  2020    9  ...         NaN          356.40  3139895.21
# 2020-10-31         164  2020   10  ...         NaN             NaN  3472743.19
# 2020-11-30         174  2020   11  ...         NaN          933.81  3309212.60
# 2020-12-31         184  2020   12  ...         NaN         1116.47  3922256.69
# 2021-01-31         194  2021    1  ...         NaN          285.71  3507363.69
#
# [253 rows x 27 columns]

# %%
df.Diesel.plot()
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(df['TotalDiesel'], model='additive', freq=12)
fig = plt.figure()  
fig = result.plot()  
fig.set_size_inches(15, 12)
plt.show()

# %% [markdown]
# ## Test de Dickey-Fuller

# %%
from statsmodels.tsa.stattools import adfuller
result=adfuller(df['TotalDiesel'])
#to help you, we added the names of every value
dict(zip(['adf', 'pvalue', 'usedlag', 'nobs', 'critical' 'values', 'icbest'],result))
# Out:
# {'adf': -0.7150917575997493,
#  'criticalvalues': {'1%': -3.4578942529658563,
#   '10%': -2.573228767361111,
#   '5%': -2.8736593200231484},
#  'icbest': 5844.155717627735,
#  'nobs': 240,
#  'pvalue': 0.842801609723639,
#  'usedlag': 12}

# %% [markdown]
# Debido a que el p-value es mayor que 0.05 no podemos rechazar la hipotesis nula

# %% [markdown]
# ## Primera diferencia para valor d

# %%
df['1difference']=df['TotalDiesel']-df['TotalDiesel'].shift(1)
df['1difference'].plot()
plt.show()

# %% [markdown]
# Repetimos el test de Dickey-Fuller

# %%
result=adfuller(df['1difference'].dropna())
dict(zip(['adf', 'pvalue', 'usedlag', 'nobs', 'critical' 'values', 'icbest'],result))
# Out:
# {'adf': -6.6201702226757595,
#  'criticalvalues': {'1%': -3.4578942529658563,
#   '10%': -2.573228767361111,
#   '5%': -2.8736593200231484},
#  'icbest': 5817.985894234085,
#  'nobs': 240,
#  'pvalue': 6.065066187182854e-09,
#  'usedlag': 11}

# %% [markdown]
# Debido a que el p-value es menor que 0.05 se rechaza la hipótesis nula en favor de la alternativa y ya podemos trabajar con el set de datos, el valor de d es 1

# %% [markdown]
# ## Análisis para valor D

# %%
df['Seasonal_Difference']=df['TotalDiesel']-df['TotalDiesel'].shift(12)
ax=df['Seasonal_Difference'].plot()
plt.show()

# %%
result=adfuller((df['Seasonal_Difference']).dropna())
dict(zip(['adf', 'pvalue', 'usedlag', 'nobs', 'critical' 'values', 'icbest'],result))
# Out:
# {'adf': -5.126871938812034,
#  'criticalvalues': {'1%': -3.4593607492757554,
#   '10%': -2.5735714042782396,
#   '5%': -2.8743015807562924},
#  'icbest': 5600.7142559214835,
#  'nobs': 228,
#  'pvalue': 1.2375723898134862e-05,
#  'usedlag': 12}

# %% [markdown]
# Debido a que el p-value es menor que 0.05 se rechaza la hipótesis nula en favor de la alternativa y ya podemos trabajar con el set de datos, el valor de D es 0

# %% [markdown]
# ## Plots de autocorrelación

# %%
fig1=plot_acf(df['1difference'].dropna())
fig2=plot_pacf(df['1difference'].dropna())
plt.show()

# %%
fig1=plot_acf(df['Seasonal_Difference'].dropna())
fig2=plot_pacf(df['Seasonal_Difference'].dropna())
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries, window = 12, cutoff = 0.01):

    #Determing rolling statistics
    rolmean = timeseries.rolling(window).mean()
    rolstd = timeseries.rolling(window).std()

    #Plot rolling statistics:
    fig = plt.figure(figsize=(12, 8))
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC', maxlag = 20 )
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    pvalue = dftest[1]
    if pvalue < cutoff:
        print('p-value = %.4f. The series is likely stationary.' % pvalue)
    else:
        print('p-value = %.4f. The series is likely non-stationary.' % pvalue)
    
    print(dfoutput)

test_stationarity(df['1difference'].dropna())
# Out:
# Results of Dickey-Fuller Test:
# p-value = 0.0000. The series is likely stationary.
# Test Statistic                -5.816650e+00
# p-value                        4.276980e-07
# #Lags Used                     1.900000e+01
# Number of Observations Used    2.320000e+02
# Critical Value (1%)           -3.458855e+00
# Critical Value (5%)           -2.874080e+00
# Critical Value (10%)          -2.573453e+00
# dtype: float64

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
model=SARIMAX(df['TotalDiesel'],order=(6,1,6),seasonal_order=(1, 0, 1, 12))
result=model.fit()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
result.resid.plot(kind='kde')

# %%
from pandas.tseries.offsets import DateOffset
new_dates=[df.index[-1]+DateOffset(months=x) for x in range(1,18)]
df_pred=pd.DataFrame(index=new_dates,columns =df.columns)
df_pred.head(20)
# Out:
#            Unnamed: 0 Anio  Mes  ... Total 1difference Seasonal_Difference
# 2021-02-28        NaN  NaN  NaN  ...   NaN         NaN                 NaN
# 2021-03-31        NaN  NaN  NaN  ...   NaN         NaN                 NaN
# 2021-04-30        NaN  NaN  NaN  ...   NaN         NaN                 NaN
# 2021-05-31        NaN  NaN  NaN  ...   NaN         NaN                 NaN
# 2021-06-30        NaN  NaN  NaN  ...   NaN         NaN                 NaN
# 2021-07-31        NaN  NaN  NaN  ...   NaN         NaN                 NaN
# 2021-08-31        NaN  NaN  NaN  ...   NaN         NaN                 NaN
# 2021-09-30        NaN  NaN  NaN  ...   NaN         NaN                 NaN
# 2021-10-31        NaN  NaN  NaN  ...   NaN         NaN                 NaN
# 2021-11-30        NaN  NaN  NaN  ...   NaN         NaN                 NaN
# 2021-12-31        NaN  NaN  NaN  ...   NaN         NaN                 NaN
# 2022-01-31        NaN  NaN  NaN  ...   NaN         NaN                 NaN
# 2022-02-28        NaN  NaN  NaN  ...   NaN         NaN                 NaN
# 2022-03-31        NaN  NaN  NaN  ...   NaN         NaN                 NaN
# 2022-04-30        NaN  NaN  NaN  ...   NaN         NaN                 NaN
# 2022-05-31        NaN  NaN  NaN  ...   NaN         NaN                 NaN
# 2022-06-30        NaN  NaN  NaN  ...   NaN         NaN                 NaN
#
# [17 rows x 29 columns]

# %%
df2=pd.concat([df,df_pred])
df2['predictionsTotalD']=result.predict(start=250,end=320)
df2[['TotalDiesel','predictionsTotalD']].plot(figsize=(20,10))
plt.show()

# %%
df2
# Out:
#            Unnamed: 0  Anio  ... Seasonal_Difference  predictionsTotalD
# 2000-01-31          3  2000  ...                 NaN                NaN
# 2000-02-29          4  2000  ...                 NaN                NaN
# 2000-03-31          5  2000  ...                 NaN                NaN
# 2000-04-30          6  2000  ...                 NaN                NaN
# 2000-05-31          7  2000  ...                 NaN                NaN
# ...               ...   ...  ...                 ...                ...
# 2022-02-28        NaN   NaN  ...                 NaN       1.188282e+06
# 2022-03-31        NaN   NaN  ...                 NaN       1.215358e+06
# 2022-04-30        NaN   NaN  ...                 NaN       1.114009e+06
# 2022-05-31        NaN   NaN  ...                 NaN       1.053473e+06
# 2022-06-30        NaN   NaN  ...                 NaN       9.779587e+05
#
# [270 rows x 30 columns]

# %%
result.forecast(16)

# %%
df2.loc[df2.Index.isna(),'Index']=df2.loc[df2.Index.isna(),'predictions']
df2

# %%
df2.Index.pct_change(periods=12).dropna().tail(20)

# %%
df2.Index.pct_change(periods=12).dropna().plot(figsize=(20,10))
